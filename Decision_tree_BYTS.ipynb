# %% [markdown]
# <a href="https://colab.research.google.com/github/harene634/Machine-Learning/blob/main/Decision_tree_BYTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Entropy-->randomness in data 0r impurities
# low entropy-->high info gain
# low entropy-->no choice
# gini and entropy are mostly same
# gini also impurity,metrics used to measure quality of split
# to identify best split->gini
# classifier,regression

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/car_data/car.data',names=['buying','maint','doors','persons','lug_boot','safety','class'])

# %%
df.tail()
# Out:
#      buying maint  doors persons lug_boot safety  class
# 1723    low   low  5more    more      med    med   good
# 1724    low   low  5more    more      med   high  vgood
# 1725    low   low  5more    more      big    low  unacc
# 1726    low   low  5more    more      big    med   good
# 1727    low   low  5more    more      big   high  vgood

# %%
df.isnull().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# class       0
# dtype: int64

# %%
df['class'].value_counts()
# Out:
# unacc    1210
# acc       384
# good       69
# vgood      65
# Name: class, dtype: int64

# %%
df['doors'].value_counts()
# Out:
# 2        432
# 3        432
# 4        432
# 5more    432
# Name: doors, dtype: int64

# %%
df[df['doors']=='4']
# Out:
#      buying  maint doors persons lug_boot safety  class
# 54    vhigh  vhigh     4       2    small    low  unacc
# 55    vhigh  vhigh     4       2    small    med  unacc
# 56    vhigh  vhigh     4       2    small   high  unacc
# 57    vhigh  vhigh     4       2      med    low  unacc
# 58    vhigh  vhigh     4       2      med    med  unacc
# ...     ...    ...   ...     ...      ...    ...    ...
# 1696    low    low     4    more      med    med   good
# 1697    low    low     4    more      med   high  vgood
# 1698    low    low     4    more      big    low  unacc
# 1699    low    low     4    more      big    med   good
# 1700    low    low     4    more      big   high  vgood
#
# [432 rows x 7 columns]

# %%
df.describe()
# Out:
#        buying  maint doors persons lug_boot safety  class
# count    1728   1728  1728    1728     1728   1728   1728
# unique      4      4     4       3        3      3      4
# top     vhigh  vhigh     2       2    small    low  unacc
# freq      432    432   432     576      576    576   1210

# %%
df['class'].unique()
# Out:
# array(['unacc', 'acc', 'vgood', 'good'], dtype=object)

# %%
#label encoidng
df['class'],class_name=pd.factorize(df['class'])

# %%
df_backup=df.copy()

# %%
df['buying'],class_name=pd.factorize(df['buying'])
df['maint'],class_name=pd.factorize(df['maint'])
df['lug_boot'],class_name=pd.factorize(df['lug_boot'])
df['safety'],class_name=pd.factorize(df['safety'])
df['doors'],class_name=pd.factorize(df['doors'])
df['persons'],class_name=pd.factorize(df['persons'])

# %%
df.tail()
# Out:
#       buying  maint  doors  persons  lug_boot  safety  class
# 1723       3      3      3        2         1       1      3
# 1724       3      3      3        2         1       2      2
# 1725       3      3      3        2         2       0      0
# 1726       3      3      3        2         2       1      3
# 1727       3      3      3        2         2       2      2

# %% [markdown]
# one hot  encoding->(get ameze)take one variable
# label encoding->(factorize)it take all varinale

# %%
x=df.drop('class',axis=1)
y=df['class']

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: class, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)

# %%
acc
# Out:
# 0.9682080924855492
