# %% [markdown]
# <a href="https://colab.research.google.com/github/harene634/Machine-Learning/blob/main/byts_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=np.array([1,2,3,4,5,6,6,7])
type(a)
# Out:
# numpy.ndarray

# %%
p=pd.Series([1,2,3,3,4,5,6,8])
type(p)
# Out:
# pandas.core.series.Series

# %%
p[2]
# Out:
# 3

# %%
p.drop(1,inplace=True)

# %%
p.iloc[3]
# Out:
# 6

# %%
p.index
# Out:
# Int64Index([0, 3, 5, 6, 7], dtype='int64')

# %%
df=pd.Series([1,2,3,4,5],index=[6,7,8,9,10])
df1=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(df)
print(df1)
print(df.iloc[1])
# Out:
# 6     1
# 7     2
# 8     3
# 9     4
# 10    5
# dtype: int64
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64
# 2

# %%
a=pd.DataFrame(df,df1)
a
# Out:
#     0
# 1 NaN
# 2 NaN
# 3 NaN
# 4 NaN
# 5 NaN

# %%
a.iloc[1]
# Out:
# 0   NaN
# Name: 2, dtype: float64

# %%
data = [("Alice", 28), ("Bob", 22), ("Charlie", 35)]

# %%
data=[["Alice", 28,'34-1-2003'],["Bob",None,None],["Charlie", None,'12-3-2004']]
data
# Out:
# [['Alice', 28, '34-1-2003'],
#  ['Bob', None, None],
#  ['Charlie', None, '12-3-2004']]

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#          0     1          2
# 0    Alice  28.0  34-1-2003
# 1      Bob   NaN       None
# 2  Charlie   NaN  12-3-2004
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py", line 3802, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "pandas/_libs/index.pyx", line 138, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/index.pyx", line 165, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 5745, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 5753, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: '1'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
# ...

# %%
df[0:2]
# Out:
#        0     1          2
# 0  Alice  28.0  34-1-2003
# 1    Bob   NaN       None

# %%
df[1:2]
# Out:
#      0   1     2
# 1  Bob NaN  None

# %%
df=pd.DataFrame(data,columns=["name","age","dob"])

# %%
df
# Out:
#       name   age        dob
# 0    Alice  28.0  34-1-2003
# 1      Bob   NaN       None
# 2  Charlie   NaN  12-3-2004

# %%
df['name']
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: name, dtype: object

# %%
df.iloc[0,0]
# Out:
# 'Alice'

# %%
s=pd.Series([1,2,3])

# %%
s.hist(bins=2)
# Out:
# <Axes: >

# %%
s=s.to_numpy()

# %%
s
s.mean()
# Out:
# 2.0

# %%
df
# Out:
#       name   age        dob
# 0    Alice  28.0  34-1-2003
# 1      Bob   NaN       None
# 2  Charlie   NaN  12-3-2004

# %%
df.mean()
# Out:
# <ipython-input-63-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# age    28.0
# dtype: float64

# %%
#none ==> nonw,' ',>,?,-,nil,np.nan(not a number)

# %%
df.isnull().sum()
# Out:
# name    0
# age     2
# dob     1
# dtype: int64

# %%
df.dropna()
# Out:
#     name   age        dob
# 0  Alice  28.0  34-1-2003

# %%
df.drop(['age'],axis=1,inplace=True)
df
# Out:
#       name        dob
# 0    Alice  34-1-2003
# 1      Bob       None
# 2  Charlie  12-3-2004

# %%
df.drop([0,2])
# Out:
#   name   dob
# 1  Bob  None

# %%
 a=np.array([1,232,4,5,67,5])

# %%
a[a>40]
# Out:
# array([232,  67])

# %%
a[a%2==0]
# Out:
# array([232,   4])

# %%
a>32
# Out:
# array([False,  True, False, False,  True, False])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   dob     2 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
a=5
type(a)
# Out:
# int

# %%
df
# Out:
#       name        dob
# 0    Alice  34-1-2003
# 1      Bob       None
# 2  Charlie  12-3-2004

# %%
df['name'].str.contains('e')
# Out:
# 0     True
# 1    False
# 2     True
# Name: name, dtype: bool

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (3, 2)
# 6
# [RangeIndex(start=0, stop=3, step=1), Index(['name', 'dob'], dtype='object')]
# 2
# name    object
# dob     object
# dtype: object
# RangeIndex(start=0, stop=3, step=1)
# Index(['name', 'dob'], dtype='object')
# [['Alice' '34-1-2003']
#  ['Bob' None]
#  ['Charlie' '12-3-2004']]

# %%
df.describe()
# Out:
#          name        dob
# count       3          2
# unique      3          2
# top     Alice  34-1-2003
# freq        1          1

# %%
df.describe(include='all')
# Out:
#          name        dob
# count       3          2
# unique      3          2
# top     Alice  34-1-2003
# freq        1          1

# %%
df.name
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# Name: name, dtype: object

# %%
df['name'][:2]
# Out:
# 0    Alice
# 1      Bob
# Name: name, dtype: object

# %%
df.loc[0][0]
# Out:
# 'Alice'

# %%
df.loc[0:1,'name']
# Out:
# 0    Alice
# 1      Bob
# Name: name, dtype: object

# %%
df['dob'][1]='3-5-2003'

# %%
df
# Out:
#       name        dob
# 0    Alice  34-1-2003
# 1      Bob   3-5-2003
# 2  Charlie  12-3-2004

# %%
r=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
r
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
r.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
type(r.item_name)
# Out:
# pandas.core.series.Series

# %%
   r.item_price=r.item_price.str.replace('$','')
   r.head()
# Out:
# <ipython-input-60-7aa2ec499d04>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   r.item_price=r.item_price.str.replace('$','')
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# 3                                                NaN      2.39
# ...

# %%
 r.item_price=r.item_price.astype(float)

# %%
r.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
type(r.item_price[0])
# Out:
# numpy.float64

# %%
#r['item_price']=r['item_price']*100

# %%
drink=r[r.item_price<1.1]

# %%
drink.head()
# Out:
#      order_id  quantity      item_name choice_description  item_price
# 28         14         1    Canned Soda       [Dr. Pepper]        1.09
# 34         17         1  Bottled Water                NaN        1.09
# 53         24         1    Canned Soda           [Sprite]        1.09
# 87         38         1  Bottled Water                NaN        1.09
# 107        47         1    Canned Soda       [Dr. Pepper]        1.09

# %%
drink.item_name.value_counts()
# Out:
# Canned Soda      84
# Bottled Water    22
# Name: item_name, dtype: int64

# %%
ch=r[r.item_name=='Chicken Bowl']

# %%
ch
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...    $11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...     $8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...     $8.49
# ...                                                 ...        ...
# ...

# %%
r.dropna(inplace=True)

# %%
r[r.choice_description.str.contains('Black Beans')].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
r[(r.item_price < 10) & (r.item_name == 'Chicken Bowl')]
# Out:
#       order_id  quantity     item_name  \
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 76          34         1  Chicken Bowl
# 78          34         1  Chicken Bowl
# 99          44         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 76    [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...        8.75
# 78    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        8.75
# 99    [Tomatillo Red Chili Salsa, [Rice, Fajita Vege...        8.75
# ...                                                 ...         ...
# ...

# %%
r['item_price']=r.sort_values('item_price')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-365070964e0b> in <cell line: 1>()
# ----> 1 r['item_price']=r.sort_values('item_price')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3968             self._setitem_array(key, value)
#    3969         elif isinstance(value, DataFrame):
# -> 3970             self._set_item_frame_value(key, value)
#    3971         elif (
#    3972             is_list_like(value)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _set_item_frame_value(self, key, value)
#    4098             len_cols = 1 if is_scalar(cols) else len(cols)
#    4099             if len_cols != len(value.columns):
# -> 4100                 raise ValueError("Columns must be same length as key")
#    4101
#    4102             # align right-hand-side columns if self.columns
#
# ...

# %%
r
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %%
r[r.choice_description.str.contains('Black Beans')].r['item_price'].sort_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-151870dba616> in <cell line: 1>()
# ----> 1 r[r.choice_description.str.contains('Black Beans')].r['item_price'].sort_values()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'r'

# %%
df=pd.read_csv('https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv')

# %%
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
df[(df.star_rating > 8) & (df.content_rating == 'R') ].sort_values('duration')
# Out:
#      star_rating                        title content_rating      genre  \
# 283          8.1                Before Sunset              R      Drama
# 225          8.1                       3-Iron              R      Crime
# 206          8.1                  Stand by Me              R  Adventure
# 172          8.2                Trainspotting              R      Drama
# 190          8.2                Life of Brian              R     Comedy
# ..           ...                          ...            ...        ...
# 184          8.2          Fanny and Alexander              R      Drama
# 40           8.5               The Green Mile              R      Crime
# 8            8.9             Schindler's List              R  Biography
# 2            9.1       The Godfather: Part II              R      Crime
# 78           8.4  Once Upon a Time in America              R      Crime
#
#      duration                                        actors_list
# ...

# %%
df[(df.star_rating > 8) & (df.content_rating == 'R') &df.actors_list=='Ewan McGregor'].sort_values('duration')
# Out:
# Empty DataFrame
# Columns: [star_rating, title, content_rating, genre, duration, actors_list]
# Index: []

# %%
df[df['actors_list'].str.contains('Liam Neeson')].sort_values(['star_rating','duration'])
# Out:
#      star_rating             title content_rating      genre  duration  \
# 924          7.5    Les Miserables          PG-13      Crime       134
# 625          7.7             Ponyo              G  Animation       101
# 640          7.7     Love Actually              R     Comedy       135
# 455          7.9             Taken          PG-13     Action        93
# 8            8.9  Schindler's List              R  Biography       195
#
#                                            actors_list
# 924  [u'Liam Neeson', u'Geoffrey Rush', u'Uma Thurm...
# 625  [u'Cate Blanchett', u'Matt Damon', u'Liam Nees...
# 640  [u'Hugh Grant', u'Martine McCutcheon', u'Liam ...
# 455  [u'Liam Neeson', u'Maggie Grace', u'Famke Jans...
# 8    [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...

# %%
df[df['actors_list'].str.contains('Liam Neeson')].sort_values(['star_rating','duration'],ascending=(False,True))
# Out:
#      star_rating             title content_rating      genre  duration  \
# 8            8.9  Schindler's List              R  Biography       195
# 455          7.9             Taken          PG-13     Action        93
# 625          7.7             Ponyo              G  Animation       101
# 640          7.7     Love Actually              R     Comedy       135
# 924          7.5    Les Miserables          PG-13      Crime       134
#
#                                            actors_list
# 8    [u'Liam Neeson', u'Ralph Fiennes', u'Ben Kings...
# 455  [u'Liam Neeson', u'Maggie Grace', u'Famke Jans...
# 625  [u'Cate Blanchett', u'Matt Damon', u'Liam Nees...
# 640  [u'Hugh Grant', u'Martine McCutcheon', u'Liam ...
# 924  [u'Liam Neeson', u'Geoffrey Rush', u'Uma Thurm...

# %%
ufo=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")

# %%
ufo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
ufo.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
ufo.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
ufo['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
d=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")

# %%
d.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
d['beer_servings'].mean()
# Out:
# 106.16062176165804

# %%
d['beer_servings'].max()
# Out:
# 376

# %%
d[d.continent=='Asia'].beer_servings.agg(['min','max','mean'])
# Out:
# min       0.000000
# max     247.000000
# mean     37.045455
# Name: beer_servings, dtype: float64

# %%
d[d.continent=='Asia'].describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count      44.000000        44.000000      44.000000
# mean       37.045455        60.840909       9.068182
# std        49.469725        84.362160      21.667034
# min         0.000000         0.000000       0.000000
# 25%         4.250000         1.000000       0.000000
# 50%        17.500000        16.000000       1.000000
# 75%        60.500000        98.000000       8.000000
# max       247.000000       326.000000     123.000000
#
#        total_litres_of_pure_alcohol
# count                     44.000000
# mean                       2.170455
# std                        2.770239
# min                        0.000000
# 25%                        0.100000
# 50%                        1.200000
# 75%                        2.425000
# max                       11.500000
